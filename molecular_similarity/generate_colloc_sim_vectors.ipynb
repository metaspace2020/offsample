# %%
import pandas as pd
import os
from os import path
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from numpy import percentile
import datetime
import gensim
from gensim import similarities
from gensim.similarities import Similarity
from gensim import models
import datetime

base_path = '/data/pixel-annot-export-v0.9/'
ann_path = path.join(base_path, 'pixel_df_list/'

# TMP DIRECTORY PATH FOR TMP GENSIM OUTPUT
opref = '/data/katya/tmp/ionsim'

ds_df_path = path.join(base_path, 'ds_df.msgpack')
ds_df = pd.read_msgpack(ds_df_path)

ion_df_path = path.join(base_path, 'ion_df.msgpack')
ion_df = pd.read_msgpack(ion_df_path)

formula_df_path = path.join(base_path, 'formula_df.msgpack')
formula_df = pd.read_msgpack(formula_df_path)

gs_path = '../GS.csv'
gs_df = pd.read_csv(gs_path)

# FDR theshold for filtering out ions
fdr = 50

sim_out_dir = 'ion_similarity_vectors'

# %%
def compute_ion_similarities(ds_ind):
    pixel_df_path = path.join(ann_path, '{}'.format(ds_ind))
    pixel_df = pd.read_msgpack(pixel_df_path)

    max_x = pixel_df['x'].max()
    max_y = pixel_df['y'].max() 

    pixel_df = pixel_df[pixel_df.fdr <= fdr]
    pixel_df.reset_index(drop=True, inplace=True)
    pixel_df = pixel_df.assign(p_ind = pixel_df.x.astype(np.int32) + (pixel_df.y.astype(np.int32) * (max_x + 1)))

    ion_corpus = []
    ions = []
    for ion_ind, ion_rows in pixel_df.groupby('ion_ind'):
        ions.append(ion_ind)
        
        # remove hot spots
        q = ion_rows.int.quantile(.99)
        ion_rows.loc[ion_rows['int'] > q, 'int'] = q 
        
        # rescale intensitiies from 0 to 1
        #ion_rows['int'] = ion_rows['int'] / ion_rows['int'].max()
        
        # build ion-pixel gensim corpus
        ion_doc = list(zip(ion_rows.p_ind, ion_rows.int))
        ion_corpus.append(ion_doc)
    
    print(datetime.datetime.now().strftime("%H:%M"), 'Ion corpus generated')
    sim_index = gensim.similarities.docsim.Similarity(opref, ion_corpus, num_features = pixel_df['p_ind'].max()+1)
    print(datetime.datetime.now().strftime("%H:%M"), 'Ion similarity computed.')
    
    pixel_df = None
    
    sim_df = pd.DataFrame(np.array(sim_index), columns = ions, index = ions)
    print(datetime.datetime.now().strftime("%H:%M"), 'Sim matrix converted into df.')
    return sim_df

# %%
# Get ion indices from dataframe
def get_ion_ind_df(ds_rows):
    result = []
    for _, row in ds_rows.iterrows():
        ion_ind_list = ion_df[ion_df.formula == row.sumFormula][ion_df.adduct == row.adduct].index.tolist()
        if len(ion_ind_list) == 0:
            print('No ion in the dictionary: ', sf, adduct)
        else:
            ion_ind = ion_ind_list[0]
            result.append(ion_ind)
    return result

# %%
for datasetId, ds_rows in gs_df.groupby('datasetId'):
    ds_row = ds_df[ds_df['id'] == datasetId]
        
    if len(ds_row.index)==0: 
        print('Dataset not found: ', datasetId)
        continue
        
    ds_name = ds_row['name'].iloc[0]
    ds_ind = ds_row.index.tolist()[0]
                
    print(datetime.datetime.now().strftime("%H:%M"), ds_name)
        
    sim_df = compute_ion_similarities(ds_ind)
    
    sim_df.to_msgpack(path.join(gs_out_dir, str(ds_ind)))
    print(datetime.datetime.now().strftime("%H:%M"), 'Df saved.')  
    
    sim_df = None
# Out:
# 07:41 AstraZeneca//CT26_xenograft
# /usr/local/lib/python3.4/dist-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# 08:26 Ion corpus generated
# 08:26 Ion similarity computed.
# 08:36 Sim matrix converted into df.
# 08:36 Df saved.
# 08:36 AstraZeneca//Rat_testis
# 08:43 Ion corpus generated
# 08:43 Ion similarity computed.
# 08:44 Sim matrix converted into df.
# 08:44 Df saved.
# 08:44 ICL//7TopRight,_17BottomRight,_27BottomLeft,_37TopLeft
# 08:45 Ion corpus generated
# 08:45 Ion similarity computed.
# 08:45 Sim matrix converted into df.
# 08:45 Df saved.
# 08:45 UoNotreDame//Untreated_6_574
# 08:46 Ion corpus generated
# 08:46 Ion similarity computed.
# 08:46 Sim matrix converted into df.
# 08:46 Df saved.
# 08:46 North Carolina State University//mouse body
# 10:43 Ion corpus generated
# 10:43 Ion similarity computed.
# 11:16 Sim matrix converted into df.
# 11:16 Df saved.
# 11:16 ICL//A51 CT S3-centroid
# 11:17 Ion corpus generated
# 11:17 Ion similarity computed.
# 11:17 Sim matrix converted into df.
# 11:17 Df saved.
# 11:17 S648 WS20 205x170 20um E110
# 11:22 Ion corpus generated
# 11:23 Ion similarity computed.
# 11:23 Sim matrix converted into df.
# 11:23 Df saved.
# 11:23 S649 WS21 155x105 15um E110
# 11:26 Ion corpus generated
# 11:26 Ion similarity computed.
# 11:27 Sim matrix converted into df.
# 11:27 Df saved.
# 11:27 MPIMM_021_QE_P_CB_0
# 12:08 Ion corpus generated
# 12:08 Ion similarity computed.
# 12:15 Sim matrix converted into df.
# 12:15 Df saved.
# 12:15 Xenograft_3_135um
# 12:23 Ion corpus generated
# 12:23 Ion similarity computed.
# 12:25 Sim matrix converted into df.
# 12:25 Df saved.
# 12:25 xenograft CT-26 S10
# 12:55 Ion corpus generated
# 12:56 Ion similarity computed.
# 13:01 Sim matrix converted into df.
# 13:01 Df saved.
# 13:01 Normal8
# 13:02 Ion corpus generated
# 13:02 Ion similarity computed.
# 13:02 Sim matrix converted into df.
# 13:02 Df saved.
# 13:02 Tumor11
# 13:03 Ion corpus generated
# 13:03 Ion similarity computed.
# 13:03 Sim matrix converted into df.
# 13:03 Df saved.
# 13:03 MP 39
# 13:16 Ion corpus generated
# 13:16 Ion similarity computed.
# 13:17 Sim matrix converted into df.
# 13:17 Df saved.
# 13:17 DESI quan_Swales
# 15:24 Ion corpus generated
# 15:25 Ion similarity computed.
# 15:57 Sim matrix converted into df.
# 15:58 Df saved.
# 15:58 ICL//LNTO22_1_3
# 15:59 Ion corpus generated
# 15:59 Ion similarity computed.
# 15:59 Sim matrix converted into df.
# 15:59 Df saved.
# 15:59 ICL//LNTO26_7_3
# 15:59 Ion corpus generated
# 15:59 Ion similarity computed.
# 15:59 Sim matrix converted into df.
# 15:59 Df saved.
# 15:59 ICL//LNTO30_16_1
# 15:59 Ion corpus generated
# 15:59 Ion similarity computed.
# 15:59 Sim matrix converted into df.
# 15:59 Df saved.
# 15:59 ICL//LNTO31_17_4
# 16:00 Ion corpus generated
# 16:00 Ion similarity computed.
# 16:00 Sim matrix converted into df.
# 16:00 Df saved.
# 16:00 ICL//LNTO41_17_2
# 16:01 Ion corpus generated
# 16:01 Ion similarity computed.
# 16:01 Sim matrix converted into df.
# 16:01 Df saved.
# 16:01 ICL//LNTO41_17_4
# 16:01 Ion corpus generated
# 16:01 Ion similarity computed.
# 16:01 Sim matrix converted into df.
# 16:01 Df saved.
# 16:01 ICL//LNTO42_17_1
# 16:02 Ion corpus generated
# 16:02 Ion similarity computed.
# 16:02 Sim matrix converted into df.
# 16:02 Df saved.
# 16:02 20170105_VS_disc2_NEDC0001_70x80_10x10
# 16:02 Ion corpus generated
# 16:02 Ion similarity computed.
# 16:02 Sim matrix converted into df.
# 16:02 Df saved.
# 16:02 2017023_ADP_GFlarvae_55x55_40x40_DMAN002
# 16:05 Ion corpus generated
# 16:05 Ion similarity computed.
# 16:06 Sim matrix converted into df.
# 16:06 Df saved.
# 16:06 Tumor17
# 16:06 Ion corpus generated
# 16:06 Ion similarity computed.
# 16:06 Sim matrix converted into df.
# 16:06 Df saved.
# 16:06 Tumor41
# 16:07 Ion corpus generated
# 16:07 Ion similarity computed.
# 16:07 Sim matrix converted into df.
# 16:07 Df saved.
# 16:07 Borderline13
# 16:07 Ion corpus generated
# 16:07 Ion similarity computed.
# 16:07 Sim matrix converted into df.
# 16:07 Df saved.
# 16:07 Borderline14
# 16:08 Ion corpus generated
# 16:08 Ion similarity computed.
# 16:08 Sim matrix converted into df.
# 16:08 Df saved.
# 16:08 Row001
# 16:25 Ion corpus generated
# 16:25 Ion similarity computed.
# 16:27 Sim matrix converted into df.
# 16:27 Df saved.
# 16:27 MPIMM_049_QE_P_BA_CF_sp3
# 16:28 Ion corpus generated
# 16:28 Ion similarity computed.
# 16:29 Sim matrix converted into df.
# 16:29 Df saved.
# 16:29 161007_WT1S1L1
# 16:37 Ion corpus generated
# 16:37 Ion similarity computed.
# 16:38 Sim matrix converted into df.
# 16:38 Df saved.
# 16:38 170321_kangaroobrain-bpyn1-pos_maxof50.0_med1r
# 16:40 Ion corpus generated
# 16:40 Ion similarity computed.
# 16:40 Sim matrix converted into df.
# 16:40 Df saved.
# 16:40 NCSU_mouse_LCC6_tumor
# 16:51 Ion corpus generated
# 16:51 Ion similarity computed.
# 16:53 Sim matrix converted into df.
# 16:53 Df saved.
# 16:53 170418_MouseBrain_pos_50um_205by129_atn0
# 17:14 Ion corpus generated
# 17:14 Ion similarity computed.
# 17:17 Sim matrix converted into df.
# 17:17 Df saved.
# 17:17 NCSU_M8_mouse_brain
# 17:24 Ion corpus generated
# 17:24 Ion similarity computed.
# 17:25 Sim matrix converted into df.
# 17:25 Df saved.
# 17:25 20170503_ADP-JS_CD1-Brain_dan005_117x143_60x60_N
# 17:26 Ion corpus generated
# 17:26 Ion similarity computed.
# 17:26 Sim matrix converted into df.
# 17:26 Df saved.
# 17:26 Dataset 2
# 17:32 Ion corpus generated
# 17:32 Ion similarity computed.
# 17:33 Sim matrix converted into df.
# 17:33 Df saved.
# 17:33 Dataset 3
# 17:39 Ion corpus generated
# 17:39 Ion similarity computed.
# 17:40 Sim matrix converted into df.
# 17:40 Df saved.
# 17:40 Dataset 4
# 17:45 Ion corpus generated
# 17:45 Ion similarity computed.
# 17:45 Sim matrix converted into df.
# 17:45 Df saved.
# 17:45 Dataset 8
# 18:01 Ion corpus generated
# 18:01 Ion similarity computed.
# 18:03 Sim matrix converted into df.
# 18:03 Df saved.
# 18:03 Dataset 16
# 18:08 Ion corpus generated
# 18:08 Ion similarity computed.
# 18:09 Sim matrix converted into df.
# 18:09 Df saved.
# 18:09 Dataset 18
# 18:15 Ion corpus generated
# 18:15 Ion similarity computed.
# 18:16 Sim matrix converted into df.
# 18:16 Df saved.
# 18:16 Dataset 21
# 18:22 Ion corpus generated
# 18:22 Ion similarity computed.
# 18:23 Sim matrix converted into df.
# 18:23 Df saved.
# 18:23 Dataset 23
# 18:31 Ion corpus generated
# 18:32 Ion similarity computed.
# 18:33 Sim matrix converted into df.
# 18:33 Df saved.
# 18:33 Dataset 27
# 18:40 Ion corpus generated
# 18:40 Ion similarity computed.
# 18:41 Sim matrix converted into df.
# 18:42 Df saved.
# 18:42 Servier_Ctrl_rat_liver_9aa
# 18:43 Ion corpus generated
# 18:43 Ion similarity computed.
# 18:43 Sim matrix converted into df.
# 18:43 Df saved.
# 18:43 Dataset 30
# 18:48 Ion corpus generated
# 18:48 Ion similarity computed.
# 18:49 Sim matrix converted into df.
# 18:49 Df saved.
# 18:49 Dataset 31
# 18:53 Ion corpus generated
# 18:53 Ion similarity computed.
# 18:54 Sim matrix converted into df.
# 18:54 Df saved.
# 18:54 CC-Esco2_centroids
# 18:55 Ion corpus generated
# 18:55 Ion similarity computed.
# 18:55 Sim matrix converted into df.
# 18:55 Df saved.
# 18:55 Esco1_centroids
# 18:56 Ion corpus generated
# 18:57 Ion similarity computed.
# 18:57 Sim matrix converted into df.
# 18:57 Df saved.
# 18:57 Esco2_centroids
# 18:58 Ion corpus generated
# 18:58 Ion similarity computed.
# 18:58 Sim matrix converted into df.
# 18:58 Df saved.
# 18:58 ST-Pseudo_centroids
# 18:59 Ion corpus generated
# 18:59 Ion similarity computed.
# 18:59 Sim matrix converted into df.
# 18:59 Df saved.
# 18:59 servier_TT_mouse_wb_fmpts_derivatization_CHCA
# 19:02 Ion corpus generated
# 19:02 Ion similarity computed.
# 19:02 Sim matrix converted into df.
# 19:02 Df saved.
# 19:02 Rat51_Section2
# 19:09 Ion corpus generated
# 19:09 Ion similarity computed.
# 19:10 Sim matrix converted into df.
# 19:10 Df saved.
# 19:10 Mousebrain_MG08_2017_GruppeA
# 19:15 Ion corpus generated
# 19:15 Ion similarity computed.
# 19:15 Sim matrix converted into df.
# 19:15 Df saved.
# 19:15 Dataset 3_recal
# 19:21 Ion corpus generated
# 19:21 Ion similarity computed.
# 19:22 Sim matrix converted into df.
# 19:22 Df saved.
# 19:22 Dataset 4_recal
# 19:27 Ion corpus generated
# 19:27 Ion similarity computed.
# 19:28 Sim matrix converted into df.
# 19:28 Df saved.
# 19:28 Dataset 26_recal
# 19:36 Ion corpus generated
# 19:36 Ion similarity computed.
# 19:37 Sim matrix converted into df.
# 19:37 Df saved.
# 19:37 slide077_animal121_rat_kidney - total ion count
# 19:39 Ion corpus generated
# 19:39 Ion similarity computed.
# 19:39 Sim matrix converted into df.
# 19:39 Df saved.
# 19:39 slide012_animal102_minipig_kidney- total ion count
# 19:39 Ion corpus generated
# 19:39 Ion similarity computed.
# 19:39 Sim matrix converted into df.
# 19:39 Df saved.
# 19:39 100um_noM2_001_Recal
# 19:46 Ion corpus generated
# 19:46 Ion similarity computed.
# 19:47 Sim matrix converted into df.
# 19:47 Df saved.
# 19:47 Servier_Ctrl_mouse_wb_median_plane_9aa
# 19:47 Ion corpus generated
# 19:47 Ion similarity computed.
# 19:47 Sim matrix converted into df.
# 19:48 Df saved.
# 19:48 Mouse_Wholebody_3
# 20:44 Ion corpus generated
# 20:44 Ion similarity computed.
# 20:52 Sim matrix converted into df.
# 20:52 Df saved.
# 20:52 Servier_Ctrl_mouse_wb_lateral_plane_DHB
# 20:53 Ion corpus generated
# 20:53 Ion similarity computed.
# 20:53 Sim matrix converted into df.
# 20:53 Df saved.
# 20:53 Servier_Ctrl_mouse_wb_median_plane_DHB
# 20:54 Ion corpus generated
# 20:54 Ion similarity computed.
# 20:55 Sim matrix converted into df.
# 20:55 Df saved.
# 20:55 20170815_CGL_MT-M.B_DAN012_NTM_42x30_100x100
# 20:56 Ion corpus generated
# 20:56 Ion similarity computed.
# 20:56 Sim matrix converted into df.
# 20:56 Df saved.
# 20:56 20170817_CGL_MT-M.B_ATP_DAN018_NTM_102x39_100x100
# 20:56 Ion corpus generated
# 20:56 Ion similarity computed.
# 20:56 Sim matrix converted into df.
# 20:56 Df saved.
# 20:56 20170905_CGL0170817_MT-MB_ATP_N_81x101_135x135
# 20:58 Ion corpus generated
# 20:58 Ion similarity computed.
# 20:58 Sim matrix converted into df.
# 20:58 Df saved.
# 20:58 Rat50_Section1
# 21:03 Ion corpus generated
# 21:03 Ion similarity computed.
# 21:03 Sim matrix converted into df.
# 21:03 Df saved.
# 21:03 MS7_20170907_DHB_pos_MouseBrain_s3_300-1800_40um_245x134_A30-JBE-Test
# 21:06 Ion corpus generated
# 21:06 Ion similarity computed.
# 21:06 Sim matrix converted into df.
# 21:06 Df saved.
# 21:06 Mouse Kidney on plastic slide 260x175 30um
# 21:27 Ion corpus generated
# 21:27 Ion similarity computed.
# 21:31 Sim matrix converted into df.
# 21:31 Df saved.
# 21:31 Mouse Kidney on coated plastic slide 270x160 30 um
# 21:44 Ion corpus generated
# 21:44 Ion similarity computed.
# 21:47 Sim matrix converted into df.
# 21:47 Df saved.
# 21:47 Mouse Kidney on coated plastic slide 300x165 30 um
# 22:21 Ion corpus generated
# 22:21 Ion similarity computed.
# 22:27 Sim matrix converted into df.
# 22:27 Df saved.
# 22:27 BRB04S-RECAL
# 22:27 Ion corpus generated
# 22:27 Ion similarity computed.
# 22:27 Sim matrix converted into df.
# 22:27 Df saved.
# 22:27 Kidney_280x140_40um_E0
# 22:35 Ion corpus generated
# 22:35 Ion similarity computed.
# 22:36 Sim matrix converted into df.
# 22:36 Df saved.
# 22:36 LNTO31_17_1-RECAL
# 22:36 Ion corpus generated
# 22:36 Ion similarity computed.
# 22:36 Sim matrix converted into df.
# 22:36 Df saved.
# 22:36 20171110_94T_RDAM_1b
# 22:36 Ion corpus generated
# 22:36 Ion similarity computed.
# 22:36 Sim matrix converted into df.
# 22:36 Df saved.
# 22:36 DESI porcine kidney interface region
# 22:38 Ion corpus generated
# 22:38 Ion similarity computed.
# 22:38 Sim matrix converted into df.
# 22:38 Df saved.
# 22:38 75um_small(focusing)_high(m/z)_dry(application)
# 22:39 Ion corpus generated
# 22:39 Ion similarity computed.
# 22:39 Sim matrix converted into df.
# 22:39 Df saved.
# 22:39 75um_small(focusing)_low(m/z)_dry(application)
# 22:39 Ion corpus generated
# 22:39 Ion similarity computed.
# 22:39 Sim matrix converted into df.
# 22:39 Df saved.
# 22:39 50um_min(focusing)_high(m/z)_dry(application)
# 22:39 Ion corpus generated
# 22:39 Ion similarity computed.
# 22:39 Sim matrix converted into df.
# 22:39 Df saved.
# 22:39 12_cylces_75um_new_submission
# 22:39 Ion corpus generated
# 22:39 Ion similarity computed.
# 22:39 Sim matrix converted into df.
# 22:39 Df saved.
# 22:39 50%meoh_8cyc_75um
# 22:40 Ion corpus generated
# 22:40 Ion similarity computed.
# 22:40 Sim matrix converted into df.
# 22:40 Df saved.
# 22:40 70%meoh_8cyc_75um
# 22:40 Ion corpus generated
# 22:40 Ion similarity computed.
# 22:40 Sim matrix converted into df.
# 22:40 Df saved.
# 22:40 20180220_mouse eye_DHB
# 22:42 Ion corpus generated
# 22:42 Ion similarity computed.
# 22:42 Sim matrix converted into df.
# 22:42 Df saved.
# 22:42 HK_S2_N2_20um_New
# 22:45 Ion corpus generated
# 22:45 Ion similarity computed.
# 22:46 Sim matrix converted into df.
# 22:46 Df saved.
# 22:46 PS_7_P7_N1_30um_New
# 22:46 Ion corpus generated
# 22:46 Ion similarity computed.
# 22:46 Sim matrix converted into df.
# 22:46 Df saved.
